# %%
presidents = read.csv("presidents.csv")

# %%
str(presidents)
# Out:
# 'data.frame':	584 obs. of  5 variables:
#  $ YEAR    : int  2008 2008 2008 2008 2008 2008 2008 2008 2008 2008 ...
#  $ DATE    : Factor w/ 195 levels " 10/4","10/1",..: 9 40 42 12 13 14 15 28 29 30 ...
#  $ OPPONENT: Factor w/ 33 levels "ARI","ATL","BAL",..: 2 11 11 11 2 2 2 19 19 5 ...
#  $ WINNER  : Factor w/ 16 levels "","*","Abe","Abe/George",..: 8 3 14 14 8 14 8 3 8 3 ...
#  $ NOTABLE : Factor w/ 534 levels "","*Presidents beaten by visiting Pittsburgh pierogies!",..: 340 1 1 1 1 1 434 406 1 339 ...

# %%
# Overall, Abe dominates, with 219 wins.
library(descr)
freq(presidents$WINNER)
# Out:
# presidents$WINNER
#            Frequency  Percent
#                    1   0.1712
# *                  1   0.1712
# Abe              219  37.5000
# Abe/George         1   0.1712
# Abe/Tom            1   0.1712
# Bill              23   3.9384
# Chester*           1   0.1712
# George           140  23.9726
# George/Abe         5   0.8562
# George/Tom         6   1.0274
# N/A                4   0.6849
# Teddy             40   6.8493
# TEDDY              4   0.6849
# Tom              132  22.6027
# Tom/George         5   0.8562
# Werth              1   0.1712
# Total            584 100.0000
# plot without title

# %%
# Since 2013, when Bill came on the scene, Abe's dominance has been significantly reduced.

freq(presidents$WINNER, presidents$YEAR>=2013)
# Out:
# presidents$WINNER
#            Frequency Percent
#                    0   0.000
# *                  0   0.000
# Abe               48  28.235
# Abe/George         0   0.000
# Abe/Tom            0   0.000
# Bill              23  13.529
# Chester*           0   0.000
# George            33  19.412
# George/Abe         0   0.000
# George/Tom         2   1.176
# N/A                2   1.176
# Teddy             40  23.529
# TEDDY              0   0.000
# Tom               22  12.941
# Tom/George         0   0.000
# Werth              0   0.000
# Total            170 100.000
# plot without title

# %% [markdown]
# All told, on any given day, you'd still want to bet on Abe, but it's a much fairer fight in the last few years.
